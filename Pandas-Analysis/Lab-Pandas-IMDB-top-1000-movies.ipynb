# %% [markdown]
# KAGGLE IMDb TOP 1000 MOVIES DATASET

# %% [markdown]
# TASK 01: LOAD AND EXPLORE THE DATASET
#
# i) LOAD THE DATASET

# %%
import pandas as pd

dataSet = pd.read_csv("imdb_top_1000.csv")

dataSet
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# ii) Display the first 5 Rows

# %%
first_five_rows = dataSet.head()
first_five_rows
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# iii) Check the datatypes of each column

# %%
print("DataTypes of Each Column:")
dataSet.dtypes
# Out:
# DataTypes of Each Column:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %% [markdown]
# iv) Find the Number of Rows & Number of Columns

# %%
rows, columns = dataSet.shape
print(f"There are {rows} Rows and {columns} Columns")
# Out:
# There are 1000 Rows and 16 Columns

# %% [markdown]
# v) Check for missing Values

# %%
missingValues = dataSet.isnull().sum()
print(f"Coulmns with number of missing Values is given by:\n{missingValues}")
# Out:
# Coulmns with number of missing Values is given by:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# TASK 02: DATA CLEANING
#
# i) Remove any Duplicate Row. If present

# %%
no_duplicate_row = dataSet.drop_duplicates()
no_duplicate_row
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# ii) Fill the missing values of dataset (e.g., Replace missing ratings with mean ratings)

# %%
dataSet["IMDB_Rating"] = dataSet["IMDB_Rating"].fillna(dataSet["IMDB_Rating"].mean())
dataSet
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# iii) Convert the Runtime column (which is in minutes as string, e.g., "120 min") to an integer

# %%
dataSet["Runtime in Int"] = dataSet["Runtime"].str.replace(" min", "", regex=False)
dataSet["Runtime in Int"] = dataSet["Runtime in Int"].astype(float).fillna(0).astype(int)

dataSet
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# TASK 03: DATA FILTERING AND SORTING
#
# i) Find all movies with an IMDb rating greater than 8.5.

# %%
movies_with_rating_greaterThan_8_5 = dataSet[dataSet["IMDB_Rating"]>8.5]
movies_with_rating_greaterThan_8_5
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
# 13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...
# 15  https://m.media-amazon.com/images/M/MV5BY2NkZj...
# ...

# %% [markdown]
# ii) List all movies that belong to the Action or Sci-Fi genre

# %%
movies_belongs_Action_Sci_fi = dataSet[dataSet["Genre"].str.contains("Action|Sci-Fi", na=False)]
movies_belongs_Action_Sci_fi
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10   https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 13   https://m.media-amazon.com/images/M/MV5BZGMxZT...
# ..                                                 ...
# 979  https://m.media-amazon.com/images/M/MV5BZTllNW...
# 982  https://m.media-amazon.com/images/M/MV5BN2VlNj...
# 983  https://m.media-amazon.com/images/M/MV5BYTU2MW...
# 985  https://m.media-amazon.com/images/M/MV5BNDQ3Mz...
# 988  https://m.media-amazon.com/images/M/MV5BMjM1Nj...
#
#                                           Series_Title Released_Year  \
# 2                                      The Dark Knight          2008
# 5        The Lord of the Rings: The Return of the King          2003
# 8                                            Inception          2010
# ...

# %% [markdown]
# iii) Find all movies that were released between 2000 and 2015

# %%
dataSet["Released_Year"] = pd.to_numeric(dataSet["Released_Year"], errors='coerce')
movies_bw_2000_2015 = dataSet[(dataSet["Released_Year"] >= 2000) & (dataSet["Released_Year"] <= 2015)]
movies_bw_2000_2015
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10   https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 13   https://m.media-amazon.com/images/M/MV5BZGMxZT...
# ..                                                 ...
# 948  https://m.media-amazon.com/images/M/MV5BMTAxMD...
# 949  https://m.media-amazon.com/images/M/MV5BYjg5ZD...
# 950  https://m.media-amazon.com/images/M/MV5BYWFlY2...
# 951  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
# 953  https://m.media-amazon.com/images/M/MV5BZTM2ZG...
#
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight         2008.0
# 5        The Lord of the Rings: The Return of the King         2003.0
# 8                                            Inception         2010.0
# ...

# %% [markdown]
# iv) Sort the dataSet based on IMDb rating in descending order.

# %%
sorted_Dataset = dataSet.sort_values(by="IMDB_Rating",ascending=False)
sorted_Dataset
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption         1994.0           A  142 min
# 1               The Godfather         1972.0           A  175 min
# 4                12 Angry Men         1957.0           U   96 min
# ...

# %% [markdown]
# TASK 04: DATA AGGREGATION & GROUPING
#
# i) Find the average IMDb ratings for each gener.

# %%
average_IMDb_ratings_for_each_gener = dataSet.groupby('Genre')['IMDB_Rating'].mean().round(3)
average_IMDb_ratings_for_each_gener
# Out:
# Genre
# Action, Adventure               8.180
# Action, Adventure, Biography    7.900
# Action, Adventure, Comedy       7.910
# Action, Adventure, Crime        7.600
# Action, Adventure, Drama        8.150
#                                 ...
# Mystery, Romance, Thriller      8.300
# Mystery, Sci-Fi, Thriller       7.800
# Mystery, Thriller               7.978
# Thriller                        7.800
# Western                         8.350
# Name: IMDB_Rating, Length: 202, dtype: float64

# %% [markdown]
# ii) Determine Which year had the most movies released.

# %%
most_released_movie = dataSet.groupby('Released_Year')['IMDB_Rating'].count()
top_year = most_released_movie.sort_values(ascending=False).idxmax()
print(f"In {top_year}, Most movies had released.")
# Out:
# In 2014.0, Most movies had released.

# %% [markdown]
# iii) Find the top 5 directors who have directed the most movies in the dataSet

# %%
top_five_directors = dataSet['Director'].value_counts().head()
top_five_directors
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Akira Kurosawa      10
# Martin Scorsese     10
# Name: count, dtype: int64

# %% [markdown]
# VISUALIZATION (MATPLOTLIB)

# %% [markdown]
# 1. Plot a Histogram of IMDB Ratings

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.hist(dataSet['IMDB_Rating'], bins = 5, color='blue', edgecolor='black')
plt.title("IMDB Ratings")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# 2. Create a barchart showing the top 10 genres with the most movies

# %%
top_genre = dataSet['Genre'].value_counts().head(10)

plt.figure(figsize=(10, 5))
plt.bar(top_genre.index, top_genre.values, color='blue')
plt.xticks(rotation=90)
plt.xlabel("Genre")
plt.ylabel("Number of Movies")
plt.title("Top 10 Most Common Genres")
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Visualize the trend of IMDb ratings over the years.

# %%
dataSet['Released_Year'] = pd.to_numeric(dataSet['Released_Year'], errors='coerce')

trend_data = dataSet.dropna(subset=['IMDB_Rating', 'Released_Year'])

avg_rating_by_year = trend_data.groupby('Released_Year')['IMDB_Rating'].mean().sort_index()

plt.figure(figsize=(12, 6))
plt.plot(avg_rating_by_year.index, avg_rating_by_year.values, marker='o', linestyle='-', color='blue')
plt.xlabel("Released Year")
plt.ylabel("Average IMDb Rating")
plt.title("Trend of IMDb Ratings Over the Years")
plt.grid(True)
plt.tight_layout()
plt.show()
